# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("../processed.csv")
df.dropna(subset=["Initial_Price"],inplace=True)
df.drop(labels=["Required_Age"],inplace=True,axis=1)

RES = df.reindex(['Initial_Price', 'Final_Price', 'Win_Flag', 'Mac_Flag', 'Linux_Flag',
       'Positive_Reviews', 'Negative_Reviews', 'Memory_MB',
       'Storage_MB','target'],axis=1)
RES.to_csv("../processed.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 df = pd.read_csv("../processed.csv")
#       2 df.dropna(subset=["Initial_Price"],inplace=True)
# ----> 3 df.drop(labels=["Required_Age"],inplace=True,axis=1)
#       5 RES = df.reindex(['Initial_Price', 'Final_Price', 'Win_Flag', 'Mac_Flag', 'Linux_Flag',
#       6        'Positive_Reviews', 'Negative_Reviews', 'Memory_MB',
#       7        'Storage_MB','target'],axis=1)
#       8 RES.to_csv("../processed.csv",index=False)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
# ...

# %%
def normalise(feature, df):
    mean = df[feature].mean()
    sd = df[feature].std()
    df[feature] = (df[feature] - mean) / sd

normalise("Initial_Price", df)
normalise("Final_Price", df)
# normalise("Required_Age", df)
normalise("Positive_Reviews", df)
normalise("Negative_Reviews", df)
normalise("Memory_MB", df)
normalise("Storage_MB", df)
df
# Out:
#        Initial_Price  Final_Price  Win_Flag  Mac_Flag  Linux_Flag  \
# 0          -0.271301    -0.258274      True      True       False
# 1          -0.322070    -0.309572      True      True       False
# 2          -0.322070    -0.309572      True     False       False
# 3           0.195385     0.213271      True     False       False
# 4          -0.098490    -0.083665      True      True        True
# ...              ...          ...       ...       ...         ...
# 59083      -0.239082    -0.225720      True     False       False
# 59084       0.018669     0.034715      True      True       False
# 59085      -0.161952    -0.147787      True     False       False
# 59086       0.273492     0.292190      True     False       False
# 59087       0.234439    -0.028421      True     False       False
#
#        Positive_Reviews  Negative_Reviews  target  Memory_MB  Storage_MB
# 0             -0.034488         -0.033031       1  -0.004171   -0.004171
# ...

# %%
y = df["target"]
X = df.drop(labels=["target"],axis=1)

X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.33, random_state=100,shuffle=True)

# %%
knn = KNeighborsClassifier(n_neighbors=5,weights='distance') 
knn.fit(X_train,y_train)
pred = knn.predict(X_test)

accuracy = accuracy_score(y_test,pred)
accuracy
# Out:
# 0.7287778129283982

# %%
knn = KNeighborsClassifier(n_neighbors=239,weights='distance') 
knn.fit(X_train,y_train)
pred = knn.predict(X_test)

accuracy = accuracy_score(y_test,pred)
accuracy
# Out:
# 0.7128018559527576
